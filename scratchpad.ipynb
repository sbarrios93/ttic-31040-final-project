# %%
from src.instance_detectors import Detector
detect = Detector()

# %%
detect.fit('./images/stopsign/reference/stop-reference.jpg')

# %%
detect.predict('./images/stopsign/lookup/stop1.jpg')
# Out:
# (array([[ 98.41209 , 222.6446  ],
#         [139.46605 , 212.71767 ],
#         [139.46605 , 212.71767 ],
#         [ 17.297422,  65.660324],
#         [ 20.579   , 149.82326 ],
#         [ 22.569988, 158.31328 ],
#         [ 25.42673 ,  68.62935 ],
#         [ 31.757784, 143.05272 ],
#         [ 33.401928, 108.091385],
#         [ 34.587063,  48.345222],
#         [ 65.85079 ,  83.945915],
#         [ 41.455025, 182.27069 ],
#         [130.40967 , 213.63432 ],
#         [ 50.45605 , 180.48207 ],
#         [ 51.555065, 132.05672 ],
#         [ 53.453636,  44.02941 ],
#         [ 53.72606 , 120.84049 ],
#         [ 54.863457,  88.87697 ],
#         [145.45064 , 121.15497 ],
#         [ 57.488888,  25.992607],
#         [ 53.027122, 108.539955],
#         [ 60.575214, 122.444984],
#         [ 60.51427 ,  33.38795 ],
#         [ 61.142467, 192.43292 ],
#         [ 65.85079 ,  83.945915],
#         [ 65.85079 ,  83.945915],
#         [ 66.78071 , 198.49976 ],
# ...

# %%
detect.reference_image
# Out:
# (248, 225)
